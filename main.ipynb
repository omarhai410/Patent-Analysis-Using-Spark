# %%
from pyspark.sql.types import ArrayType, StringType

from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, col, year, avg, length, desc, split, concat_ws, count, isnull, size, udf

# Créer une session Spark avec le connecteur MongoDB
spark = SparkSession.builder \
    .appName("Analyse des données MongoDB") \
    .config("spark.mongodb.input.uri", "mongodb://localhost:27017/spark.data") \
    .config("spark.mongodb.output.uri", "mongodb://localhost:27017/spark.data") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.1") \
    .getOrCreate()

# Charger les données depuis MongoDB en tant que DataFrame Spark
df = spark.read.format("com.mongodb.spark.sql.DefaultSource").load()

# Distribution des brevets par année de publication
distribution_par_annee = df.groupBy(year("publication_date").alias("year")).count().orderBy("year")

# Distribution des brevets par pays
distribution_par_pays = df.groupBy("country").count().orderBy(desc("count"))

# Distribution des brevets par inventeur ou titulaire actuel
distribution_par_inventeur = df.select(explode("current_assignees").alias("assignee")).groupBy("assignee").count().orderBy(desc("count"))

# Distribution des brevets par langue
distribution_par_langue = df.groupBy("other_language").count().orderBy(desc("count"))

# Concaténation des descriptions en une seule chaîne de caractères
concat_descriptions = df.select(concat_ws(" ", "description").alias("concat_description"))

# Tokenisation des descriptions
mots_descriptions = concat_descriptions.select(explode(split("concat_description", "\\s+")).alias("mot")).filter(col("mot") != "")

# Concaténation des revendications en une seule chaîne de caractères
concat_revendications = df.select(concat_ws(" ", "claims").alias("concat_claims"))

# Tokenisation des revendications
mots_revendications = concat_revendications.select(explode(split("concat_claims", "\\s+")).alias("mot")).filter(col("mot") != "")

# Analyse de la longueur moyenne des descriptions et des revendications
longueur_moyenne_description = concat_descriptions.select(avg(length("concat_description")).alias("avg_description_length"))
longueur_moyenne_revendications = concat_revendications.select(avg(length("concat_claims")).alias("avg_claims_length"))

# Calcul de la fréquence des mots dans les descriptions
freq_mots_descriptions = mots_descriptions.groupBy("mot").count().orderBy(desc("count"))

# Calcul de la fréquence des mots dans les revendications
freq_mots_revendications = mots_revendications.groupBy("mot").count().orderBy(desc("count"))

# Distribution des brevets par inventeur
distribution_par_inventeur = df.select(explode("inventors").alias("inventor")) \
                                .groupBy("inventor").agg(count("*").alias("nombre_brevets")) \
                                .orderBy(col("nombre_brevets").asc())

# Distribution des brevets par date de publication
distribution_par_date_publication = df.groupBy("publication_date").count().orderBy("publication_date")


# Affichage des résultats
print("Distribution des brevets par inventeur :")
distribution_par_inventeur.show(truncate=False)


# Affichage des résultats
print("Distribution des brevets par année de publication :")
distribution_par_annee.show(truncate=False)

print("Distribution des brevets par pays :")
distribution_par_pays.show(truncate=False)

print("Distribution des brevets par inventeur ou titulaire actuel :")
distribution_par_inventeur.show(truncate=False)

print("Distribution des brevets par langue :")
distribution_par_langue.show(truncate=False)

print("Longueur moyenne des descriptions :")
longueur_moyenne_description.show()

print("Longueur moyenne des revendications :")
longueur_moyenne_revendications.show()

print("Mots les plus fréquents dans les descriptions :")
freq_mots_descriptions.show(truncate=False)

print("Mots les plus fréquents dans les revendications :")
freq_mots_revendications.show(truncate=False)

# Distribution des brevets par pays d'origine et année de publication
distribution_par_pays_et_annee = df.groupBy("country", year("publication_date").alias("year")).count().orderBy("country", "year")

# Affichage des résultats
print("Distribution des brevets par pays d'origine et année de publication :")
distribution_par_pays_et_annee.show(truncate=False)

# Explode des revendications pour obtenir une ligne par revendication
df_exploded = df.select("country", explode("claims").alias("claim"))

# Distribution des brevets par pays et nombre de revendications
distribution_par_pays_et_revendications = df_exploded.groupBy("country").count().orderBy(col("count").desc())

# Affichage des résultats
print("Distribution des brevets par pays et nombre de revendications :")
distribution_par_pays_et_revendications.show(truncate=False)
# Out:
# Distribution des brevets par inventeur :
# +--------------------------+--------------+
# |inventor                  |nombre_brevets|
# +--------------------------+--------------+
# |Alison Sunstrum           |1             |
# |Yosef YOVEL               |1             |
# |Thierry Michelon          |1             |
# |Arno Ruckelshausen        |1             |
# |Frank Bernard             |1             |
# |Roee FINKELSHTAIN         |1             |
# |Gregory Francis Chakwan Lu|1             |
# |Frederic Bataille         |1             |
# |Salah Sukkarieh           |1             |
# |Alfred C. Dadson          |1             |
# |Oddgeir HUSØY             |1             |
# |Gabor Kosa                |1             |
# |Martin LARSÉN             |1             |
# |Jon Friedman              |1             |
# |Julien Mercier            |1             |
# |Andreas Linz              |1             |
# |Jonathan BINNEY           |1             |
# |Bernard Certain           |1             |
# |Jung Youl Park            |1             |
# |Alexis MATHIEU            |1             |
# +--------------------------+--------------+
# only showing top 20 rows
#
# Distribution des brevets par année de publication :
# +----+-----+
# |year|count|
# +----+-----+
# |NULL|826  |
# |1900|1    |
# |1964|1    |
# |1969|1    |
# |1974|1    |
# |1977|1    |
# |1978|1    |
# |1980|3    |
# |1981|9    |
# |1982|11   |
# |1983|13   |
# |1984|15   |
# |1985|10   |
# |1986|8    |
# |1987|14   |
# |1988|15   |
# |1989|18   |
# |1990|26   |
# |1991|11   |
# |1992|10   |
# +----+-----+
# only showing top 20 rows
#
# Distribution des brevets par pays :
# +----------------------+-----+
# |country               |count|
# +----------------------+-----+
# |NULL                  |818  |
# |European Patent Office|655  |
# |France                |645  |
# |China                 |493  |
# |WIPO (PCT)            |300  |
# |United States         |218  |
# |Japan                 |93   |
# |Canada                |69   |
# |South Korea           |51   |
# |Russia                |39   |
# |Belgium               |34   |
# |Spain                 |23   |
# |Australia             |23   |
# |Taiwan                |12   |
# |Hungary               |12   |
# |Switzerland           |8    |
# |Germany               |7    |
# |Brazil                |7    |
# |OAPI                  |6    |
# |Luxembourg            |6    |
# +----------------------+-----+
# only showing top 20 rows
#
# Distribution des brevets par inventeur ou titulaire actuel :
# +------------------+--------------+
# |inventor          |nombre_brevets|
# +------------------+--------------+
# |Troy M. Swartwood |1             |
# |Tyler D Schleicher|1             |
# |Hervé Rolland     |1             |
# |Andreas MÜLLER    |1             |
# |Frederic Bataille |1             |
# |Thierry Ferreira  |1             |
# |Scott MASSEY      |1             |
# |Sergyl Clerget    |1             |
# |Shlomo ALMOG      |1             |
# |Ralf Becker       |1             |
# |Alexander J. Gould|1             |
# |David Bouchez     |1             |
# |Mikael Willgert   |1             |
# |Alfred C. Dadson  |1             |
# |Dolf Van Der Veen |1             |
# |Juanshu Shen      |1             |
# |Stefan Hengstler  |1             |
# |Gerald Germain    |1             |
# |Roee FINKELSHTAIN |1             |
# |Oliver Meil       |1             |
# +------------------+--------------+
# only showing top 20 rows
#
# Distribution des brevets par langue :
# +------------------------+-----+
# |other_language          |count|
# +------------------------+-----+
# |English                 |1777 |
# |NULL                    |818  |
# |German                  |597  |
# |French                  |78   |
# |Hungarian               |12   |
# |Bao Tran                |4    |
# |Farrokh F. Radjy        |4    |
# |David Naylor            |4    |
# |Stefan Battlogg         |3    |
# |Oleg Sinyavskiy         |3    |
# |Pouria Ghods            |3    |
# |Jasvir Singh Gill       |3    |
# |Dean Paul Forgeron      |2    |
# |Sanford Allan Victor    |2    |
# |Steven M. Hoffberg      |2    |
# |David H. Parker         |2    |
# |Michael Beaugavin Markov|2    |
# |Eugenio Minvielle       |2    |
# |Maxime Jean Jerome Bilet|2    |
# |Timothy McCullough      |2    |
# +------------------------+-----+
# only showing top 20 rows
#
# Longueur moyenne des descriptions :
# +----------------------+
# |avg_description_length|
# +----------------------+
# |     52823.44734601192|
# +----------------------+
#
# Longueur moyenne des revendications :
# +------------------+
# | avg_claims_length|
# +------------------+
# |1430.2012489355664|
# +------------------+
#
# Mots les plus fréquents dans les descriptions :
# +---+------+
# |mot|count |
# +---+------+
# |de |805233|
# |the|676161|
# |of |383528|
# |a  |363916|
# |la |334599|
# |to |246423|
# |and|240317|
# |et |218512|
# |à  |216397|
# |le |190285|
# |un |174418|
# |in |170353|
# |des|161727|
# |en |160946|
# |or |152404|
# |les|145465|
# |une|138850|
# |is |127779|
# |be |125164|
# |par|124524|
# +---+------+
# only showing top 20 rows
#
# Mots les plus fréquents dans les revendications :
# +--------------+-----+
# |mot           |count|
# +--------------+-----+
# |de            |36419|
# |la            |15804|
# |à             |12924|
# |en            |12013|
# |des           |11930|
# |et            |10214|
# |the           |9650 |
# |un            |9407 |
# |selon         |9347 |
# |le            |8654 |
# |une           |7562 |
# |ou            |6173 |
# |les           |6140 |
# |dans          |6011 |
# |of            |5677 |
# |que           |5578 |
# |revendications|5484 |
# |ce            |5374 |
# |du            |4808 |
# |au            |4785 |
# +--------------+-----+
# only showing top 20 rows
#
# Distribution des brevets par pays d'origine et année de publication :
# +---------+----+-----+
# |country  |year|count|
# +---------+----+-----+
# |NULL     |NULL|818  |
# |Australia|2006|2    |
# |Australia|2007|2    |
# |Australia|2008|1    |
# |Australia|2009|4    |
# |Australia|2013|1    |
# |Australia|2014|2    |
# |Australia|2015|3    |
# |Australia|2017|1    |
# |Australia|2018|2    |
# |Australia|2019|2    |
# |Australia|2020|1    |
# |Australia|2021|2    |
# |Austria  |2014|1    |
# |Belgium  |NULL|8    |
# |Belgium  |1900|1    |
# |Belgium  |1964|1    |
# |Belgium  |1969|1    |
# |Belgium  |1974|1    |
# |Belgium  |1978|1    |
# +---------+----+-----+
# only showing top 20 rows
#
# Distribution des brevets par pays et nombre de revendications :
# +----------------------+-----+
# |country               |count|
# +----------------------+-----+
# |European Patent Office|7217 |
# |France                |4456 |
# |Japan                 |1669 |
# |South Korea           |891  |
# |WIPO (PCT)            |437  |
# |Germany               |259  |
# |Spain                 |155  |
# |Belgium               |130  |
# |China                 |73   |
# |Australia             |66   |
# |OAPI                  |51   |
# |Brazil                |27   |
# |Canada                |24   |
# |Switzerland           |16   |
# |Austria               |14   |
# |Eurasian Patent Office|12   |
# +----------------------+-----+

# %%
from difflib import SequenceMatcher
from pyspark.sql.functions import col

# Fonction pour calculer le pourcentage de similarité entre deux chaînes de caractères
def similarite(titre1, titre2):
    return SequenceMatcher(None, titre1, titre2).ratio() * 100

# Fonction pour calculer la similarité entre tous les titres non vides dans le DataFrame
def calculer_similarite_entre_titres(df):
    similarites = []
    titres_non_vides = df.filter(col("title").isNotNull()).select("title").collect()
    for i in range(len(titres_non_vides)):
        titre1 = titres_non_vides[i]["title"].lower()
        for j in range(i+1, len(titres_non_vides)):
            titre2 = titres_non_vides[j]["title"].lower()
            # Vérifier si les titres ne sont pas vides et que la similarité n'est pas de 100%
            if titre1 and titre2 and titre1 != titre2:
                pourcentage_similarite = similarite(titre1, titre2)
                similarites.append((titre1, titre2, pourcentage_similarite))
    return similarites

# Calculer les similarités entre tous les titres non vides
similarites_titres = calculer_similarite_entre_titres(df)

# Filtrer les similarités pour ne garder que celles qui ont une similarité inférieure à 60%
similarites_sous_60 = [sim for sim in similarites_titres if sim[2] < 60]

# Trier les similarités filtrées par ordre décroissant de similarité
top_similarites_sous_60 = sorted(similarites_sous_60, key=lambda x: x[2], reverse=True)[:100]

# Afficher les 20 meilleures paires de titres avec une similarité inférieure à 60%
for titre1, titre2, pourcentage_similarite in top_similarites_sous_60:
    print(f"Titre 1 : {titre1}, Titre 2 : {titre2}, Pourcentage de similarité : {pourcentage_similarite}%")
# Out:
# Titre 1 : a method for obtaining data from an image of an object of a user that has a biometric characteristic of the user, Titre 2 : method for verifying the identity of a user by identifying an object within an image that has a biometric characteristic of the user and mobile device for executing the method, Pourcentage de similarité : 59.93031358885017%
# Titre 1 : dispositif de pulverisation de produits de traitement pour vegetaux, Titre 2 : dispositif pour l'application de micro-ondes en vue du traitement d'un materiau., Pourcentage de similarité : 59.863945578231295%
# Titre 1 : method and apparatus for packing bunches of flowers into sleeves, Titre 2 : the method and apparatus for determining the number of living cells in a test fluid, Pourcentage de similarité : 59.863945578231295%
# Titre 1 : composition comprenant du henne et/ou de l'indigo, une huile et un saccharide, et procede de coloration capillaire la mettant en œuvre, Titre 2 : composition a base de poudres de plante(s) indigofere(s) et de beurres, procede de coloration capillaire mettant en oeuvre cette composition, Pourcentage de similarité : 59.854014598540154%
# Titre 1 : procédé et dispositif de supervision de traitement d'une culture, Titre 2 : procede et dispositif d'assistance aux manoeuvres de garage d'un vehicule, Pourcentage de similarité : 59.854014598540154%
# Titre 1 : dispositif et procede pour le developement de formulations, Titre 2 : dispositif et procede de traitement des sols par aeration a stockage de dechets, Pourcentage de similarité : 59.854014598540154%
# Titre 1 : procede et dispositif d'aide a la preconisation de traitement d'une culture, Titre 2 : procédé et installation de traitement d'hygiénisation de boues, Pourcentage de similarité : 59.854014598540154%
# Titre 1 : dispositif de deshumidification de produits alimentaires tel le miel, Titre 2 : dispositif d'irradiation de rayons solaires pour traitements medicaux, Pourcentage de similarité : 59.854014598540154%
# Titre 1 : clou d'arpentage et systeme d'identification a distance d'un tel clou, Titre 2 : sonde optique de deminage et procede d'identification d'un materiau., Pourcentage de similarité : 59.854014598540154%
# Titre 1 : dispositif de lutte et procede de lutte contre des plantes, Titre 2 : dispositif et procede de traitement des sols par aeration a stockage de dechets, Pourcentage de similarité : 59.854014598540154%
# Titre 1 : structures fibreuses perforees et ses procedes de fabrication, Titre 2 : granulats legers d'origine vegetale et leur procede de fabrication, Pourcentage de similarité : 59.84251968503938%
# Titre 1 : dispositif de production de denrees vegetales en terre hors sol, Titre 2 : dispositif de detection de piquets dans des cultures en espalier, Pourcentage de similarité : 59.84251968503938%
# Titre 1 : machine pour la recolte du tabac et autres plantes analogues, Titre 2 : machine de palissage pour la vigne ou autres plantes ou arbrisseaux, Pourcentage de similarité : 59.84251968503938%
# Titre 1 : dispositif d'irrigation avec detection de niveau de remplissage, Titre 2 : dispositif de detection de piquets dans des cultures en espalier, Pourcentage de similarité : 59.84251968503938%
# Titre 1 : procédé et dispositif de traitement de végétaux après récolte, Titre 2 : procede et dispositif de torrefaction de matiere ligneuse vegetale, Pourcentage de similarité : 59.84251968503938%
# Titre 1 : procede et dispositif de mesure de la couleur d'un objet, Titre 2 : dispositif et procede de mesure de hauteur de couvert vegetal, Pourcentage de similarité : 59.82905982905983%
# Titre 1 : procede et dispositif de mesure de la couleur d'un objet, Titre 2 : procédé et dispositif de traitement de végétaux après récolte, Pourcentage de similarité : 59.82905982905983%
# Titre 1 : composition cosmetique ou dermatologique et son utilisation, Titre 2 : composition cosmetique comprenant un colorant hydrosoluble, Pourcentage de similarité : 59.82905982905983%
# Titre 1 : composition cosmetique ou dermatologique et son utilisation, Titre 2 : composition cosmetique comprenant un colorant hydrosoluble, Pourcentage de similarité : 59.82905982905983%
# Titre 1 : systeme de traitement automatique, notamment de tonte, d'une zone de travail, Titre 2 : systeme de commande d'un engin de travail, Pourcentage de similarité : 59.82905982905983%
# Titre 1 : dispositif d'interdiction d'une zone à un animal domestique et procédé de mise en oeuvre d'un tel dispositif, Titre 2 : dispositif permettant de retirer des dechets d'une nappe de fibres en mouvement et carde equipee d'un tel dispositif, Pourcentage de similarité : 59.82142857142857%
# Titre 1 : procede et dispositif de mesure de la couleur d'un objet, Titre 2 : procede et systeme de pilotage d'un reservoir d'eau, Pourcentage de similarité : 59.813084112149525%
# Titre 1 : procédé de détection d'organismes dans un échantillon dilué, Titre 2 : procédé de détection et discrimination de gestes, Pourcentage de similarité : 59.813084112149525%
# Titre 1 : dispositif de traitement de materiel vegetal, Titre 2 : dispositif de production de denrees vegetales en terre hors sol, Pourcentage de similarité : 59.813084112149525%
# Titre 1 : procédé et installation de traitement d'hygiénisation de boues, Titre 2 : procédé d'estimation du mouvement d'un piéton, Pourcentage de similarité : 59.813084112149525%
# Titre 1 : system and method for contamination monitoring, Titre 2 : remote access system and method for plant pathogen management, Pourcentage de similarité : 59.813084112149525%
# Titre 1 : system and method for contamination monitoring, Titre 2 : system and method for transport security control and tracking, Pourcentage de similarité : 59.813084112149525%
# Titre 1 : procédé et dispositif de pesage, Titre 2 : procédé et dispositif de maintenance d'une installation électrique, Pourcentage de similarité : 59.79381443298969%
# Titre 1 : dispositif de contrôle de traitement agricole, Titre 2 : dispositif de moulage d'objets creux a parois minces, Pourcentage de similarité : 59.79381443298969%
# Titre 1 : dispositif de contrôle de traitement agricole, Titre 2 : dispositif de moulage d'objets creux a parois minces, Pourcentage de similarité : 59.79381443298969%
# Titre 1 : dispositif de traitement photo-biologique amélioré, Titre 2 : dispositif de traitement des cheveux et procédé, Pourcentage de similarité : 59.79381443298969%
# Titre 1 : dispositif et procédé de compactage d'une poudre, Titre 2 : dispositif de preparation d'une boisson fermentee, Pourcentage de similarité : 59.79381443298969%
# Titre 1 : procede et dispositif d'autoguidage pour machines agricoles automotrices, Titre 2 : procede et dispositif d'autoguidage d'un vehicule entre des obstacles dresses, et vehicule muni de ce dispositif, Pourcentage de similarité : 59.78260869565217%
# Titre 1 : dispositif mécanisé pour la plantation de végétaux, Titre 2 : dispositif de prehension de materiaux, Pourcentage de similarité : 59.77011494252874%
# Titre 1 : dispositif de contrôle de traitement agricole, Titre 2 : dispositif concentrateur d'energie solaire, Pourcentage de similarité : 59.77011494252874%
# Titre 1 : dispositif de contrôle de traitement agricole, Titre 2 : dispositif concentrateur d'energie solaire, Pourcentage de similarité : 59.77011494252874%
# Titre 1 : dispositif de pollinisation a usage agricole, Titre 2 : outil de géolocalisation et de cartographie, Pourcentage de similarité : 59.77011494252874%
# Titre 1 : dispositif de distribution d'un produit cosmetique, Titre 2 : dispositif de decoration de monuments, Pourcentage de similarité : 59.77011494252874%
# Titre 1 : composition cosmetique comprenant un polyphenol en association avec un sucre, Titre 2 : composition cosmetique comprenant une combinaison de scleroglucane et de caroube, et utilisations., Pourcentage de similarité : 59.77011494252874%
# Titre 1 : installation de panneaux de cellules photovoltaïques, Titre 2 : installation de séchage de végétaux, Pourcentage de similarité : 59.77011494252874%
# Titre 1 : procédé et système d'enrichissement d'un contenu numérique représentatif d'une conversation, Titre 2 : procede et systeme de traitement de donnees pour la preparation d'un jeu de donnees, Pourcentage de similarité : 59.77011494252874%
# Titre 1 : device and method for foot exercise, Titre 2 : input device and method of operating an input device, Pourcentage de similarité : 59.77011494252874%
# Titre 1 : dispositif de traitement des cheveux et procédé, Titre 2 : ensemble de traitement de vieux papiers., Pourcentage de similarité : 59.77011494252874%
# Titre 1 : installation de conversion de l'energie des vagues, Titre 2 : installation pour l'elevage d'animaux, Pourcentage de similarité : 59.77011494252874%
# Titre 1 : système et procédé de culture, Titre 2 : dispositif et procédé de compactage d'une poudre, Pourcentage de similarité : 59.74025974025974%
# Titre 1 : dispositif d'infusion a variation de pression, Titre 2 : dispositif porteur d'information, Pourcentage de similarité : 59.74025974025974%
# Titre 1 : composition cosmetique comprenant un polyphenol en association avec un sucre, Titre 2 : composition cosmetique comprenant un extrait d'amande douce et procede de soin, Pourcentage de similarité : 59.74025974025974%
# Titre 1 : procede de production de gaz methane, Titre 2 : procede de quantification d'une biomasse., Pourcentage de similarité : 59.74025974025974%
# Titre 1 : procede de production de gaz methane, Titre 2 : mobile production system for cement panel, Pourcentage de similarité : 59.74025974025974%
# Titre 1 : dispositif pour la récolte du tabac, Titre 2 : dispositif de capsage de feuilles de tabac, Pourcentage de similarité : 59.74025974025974%
# Titre 1 : particle separation systems and methods, Titre 2 : personal care compositions and methods, Pourcentage de similarité : 59.74025974025974%
# Titre 1 : dispositif de traitement de matières kératiniques humaines, Titre 2 : dispositif destine au traitement de residus organiques et procedes de mise en óoeuvre., Pourcentage de similarité : 59.72222222222222%
# Titre 1 : dispositif et procede de mesure de hauteur de couvert vegetal, Titre 2 : dispositif de contrôle d'une sonde de mesure de pression d'un écoulement., Pourcentage de similarité : 59.70149253731343%
# Titre 1 : dispositif de traitement par photothérapie, Titre 2 : dispositif de phenotypage, Pourcentage de similarité : 59.70149253731343%
# Titre 1 : procédé de préparation d'une composition cosmétique et appareil pour la mise en oeuvre d'un tel procédé, Titre 2 : procédé de nettoyage des matières kératiniques humaines et kit pour la mise en œuvre de ce procédé, Pourcentage de similarité : 59.70149253731343%
# Titre 1 : procédé et dispositif de commande automatique de l'irrigation de végétaux, Titre 2 : procédé et dispositif de traitement de végétaux après récolte, Pourcentage de similarité : 59.70149253731343%
# Titre 1 : compositions contenant des melanges de fibres fermentescibles., Titre 2 : composition cosmetique comprenant des esters d'acide behenique, Pourcentage de similarité : 59.67741935483871%
# Titre 1 : procédé de détection d'organismes dans un échantillon dilué, Titre 2 : procédé de manipulation de microgouttes incluant des échantillons, Pourcentage de similarité : 59.67741935483871%
# Titre 1 : composition gelifiee comprenant une dispersion d'agregats solides., Titre 2 : composition cosmetique comprenant un colorant hydrosoluble, Pourcentage de similarité : 59.67741935483871%
# Titre 1 : composition gelifiee comprenant une dispersion d'agregats solides., Titre 2 : composition cosmetique comprenant un colorant hydrosoluble, Pourcentage de similarité : 59.67741935483871%
# Titre 1 : procédé de production d'énergie électrique à partir de biomasse, Titre 2 : systeme de production de sucre a partir de matieres vegetales, Pourcentage de similarité : 59.67741935483871%
# Titre 1 : dispositif de protection des vignes contre le gel et son procede d`installation, Titre 2 : dispositif de protection de cultures en rangs, Pourcentage de similarité : 59.67741935483871%
# Titre 1 : procede et installation, notamment pour la germination de graines de cereales, Titre 2 : procede et installation de traitement du verre., Pourcentage de similarité : 59.67741935483871%
# Titre 1 : dispositif de deshumidification de produits alimentaires tel le miel, Titre 2 : dispositif de stimulation de la pompe veineuse plantaire, Pourcentage de similarité : 59.67741935483871%
# Titre 1 : procédé de fabrication de composant de chaussure sur mesure, Titre 2 : procédé de manipulation de microgouttes incluant des échantillons, Pourcentage de similarité : 59.67741935483871%
# Titre 1 : procédé et dispositif de pesage, Titre 2 : dispositif de vaporisation, Pourcentage de similarité : 59.64912280701754%
# Titre 1 : dispersions stables de gouttes comprenant un agent gelifiant, Titre 2 : émulsions doubles comprenant une phase grasse gélifiée, Pourcentage de similarité : 59.64912280701754%
# Titre 1 : installation d'arrosage et procédé de commande d'arrosage, Titre 2 : installation et procede de traitement de deblais limoneux, Pourcentage de similarité : 59.64912280701754%
# Titre 1 : dispositif de stimulation de la pompe veineuse plantaire, Titre 2 : dispositif de lutte et procede de lutte contre des plantes, Pourcentage de similarité : 59.64912280701754%
# Titre 1 : hydroponic growing system, Titre 2 : electronic device cooling system, Pourcentage de similarité : 59.64912280701754%
# Titre 1 : installation de protection de plantes cultivees en rang, Titre 2 : procédé et installation d'identification des bases d'un adn, Pourcentage de similarité : 59.64912280701754%
# Titre 1 : installation de traitement d'articles alimentaires, Titre 2 : installation de chargement automatique de sachets dans une boîte, Pourcentage de similarité : 59.64912280701754%
# Titre 1 : installation de protection de plantes cultivees en rang, Titre 2 : procédé et installation d'identification des bases d'un adn, Pourcentage de similarité : 59.64912280701754%
# Titre 1 : food preparation system, Titre 2 : portable energy generation systems, Pourcentage de similarité : 59.64912280701754%
# Titre 1 : procede de detection et de quantification d'analytes d'interet dans un liquide et dispositif de mise en oeuvre, Titre 2 : procede de regulation du debit de poudre transportee par un flux d'air, et dispositif pour sa mise en oeuvre, Pourcentage de similarité : 59.63302752293578%
# Titre 1 : procede de detection et de quantification d'analytes d'interet dans un liquide et dispositif de mise en oeuvre, Titre 2 : procede de regulation du debit de poudre transportee par un flux d'air, et dispositif pour sa mise en oeuvre, Pourcentage de similarité : 59.63302752293578%
# Titre 1 : procede et installation de preparation de brochettes de produits vegetaux et brochettes obtenues, Titre 2 : procédé et installation de ventilation et de régulation pour le traitement d'un produit organique humide et fermentescible, Pourcentage de similarité : 59.63302752293578%
# Titre 1 : dispositif et procédé d'arrosage pivotant héliotrope, Titre 2 : dispositif et procede d'analyse optique de documents, Pourcentage de similarité : 59.61538461538461%
# Titre 1 : installation de panneaux de cellules photovoltaïques, Titre 2 : installation de manutention de tablettes sous serres, Pourcentage de similarité : 59.61538461538461%
# Titre 1 : dispositif de manutention de balles de vegetaux, Titre 2 : dispositif de destruction de nuisibles et système associé, Pourcentage de similarité : 59.61538461538461%
# Titre 1 : dispositif d'animation de forme et son bloc de commande, Titre 2 : dispositif de preparation d'une boisson fermentee, Pourcentage de similarité : 59.61538461538461%
# Titre 1 : dispositif de pulverisation de produits de traitement pour vegetaux, Titre 2 : dispositif de prehension de materiaux, Pourcentage de similarité : 59.61538461538461%
# Titre 1 : dispositif de pulverisation de produits de traitement pour vegetaux, Titre 2 : dispositif de decoration de monuments, Pourcentage de similarité : 59.61538461538461%
# Titre 1 : installation de conditionnement robotisee, Titre 2 : installation de stockage et de subirrigation de plantes en pots, Pourcentage de similarité : 59.61538461538461%
# Titre 1 : systems and methods for robotic fruit harvesting, Titre 2 : systems and methods of storing combustion waste products, Pourcentage de similarité : 59.61538461538461%
# Titre 1 : bridged element for detection of a target substance, Titre 2 : system and method for detecting a substance in liquid, Pourcentage de similarité : 59.61538461538461%
# Titre 1 : système de production d’énergie électrique adapté aux cultures, Titre 2 : dispositif de production d'énergie mécanique, d'énergie électrique et procédé à cet effet, Pourcentage de similarité : 59.60264900662252%
# Titre 1 : automated gravimetric screening platform system and method, Titre 2 : plant phenometrics system and method, Pourcentage de similarité : 59.57446808510638%
# Titre 1 : dispositif et procede de mesure d’au moins un parametre d’arrachage d’une plante, Titre 2 : dispositif et procede de mesure de hauteur de couvert vegetal, Pourcentage de similarité : 59.57446808510638%
# Titre 1 : dispositif de mesure de la spasticite, Titre 2 : dispositif de destruction de nuisibles et système associé, Pourcentage de similarité : 59.57446808510638%
# Titre 1 : dispositif d'infusion a variation de pression, Titre 2 : dispositif d'evaporation et pesee d'echantillons., Pourcentage de similarité : 59.57446808510638%
# Titre 1 : dispositif d'infusion a variation de pression, Titre 2 : dispositif de preparation d'une boisson fermentee, Pourcentage de similarité : 59.57446808510638%
# Titre 1 : dispositif de protection de cultures en rangs, Titre 2 : dispositif de preparation d'une boisson fermentee, Pourcentage de similarité : 59.57446808510638%
# Titre 1 : dispositif de protection de cultures en rangs, Titre 2 : dispositif de detection optique de gaz a distance, Pourcentage de similarité : 59.57446808510638%
# Titre 1 : dispositif de manutention de balles de vegetaux, Titre 2 : dispositif de traitement des cheveux et procédé, Pourcentage de similarité : 59.57446808510638%
# Titre 1 : dispositif de lutte et procede de lutte contre des plantes, Titre 2 : dispositif de recolte et son procede, Pourcentage de similarité : 59.57446808510638%
# Titre 1 : machine pour récolter des plantes potagères., Titre 2 : appareil pour préparer des pellicules de polymère., Pourcentage de similarité : 59.57446808510638%
# Titre 1 : composition épaississante d'huiles polaires ou apolaires, Titre 2 : composition copolymérique épaississante d'huiles polaires ou apolaires, comprenant au moins une huile et au moins un poly(itaconate), Pourcentage de similarité : 59.57446808510638%
# Titre 1 : system and method for monitoring of plants or machinery using a mobile sensor device, Titre 2 : system and method for extracting oil from plant materials, Pourcentage de similarité : 59.57446808510638%
# Titre 1 : systems and method for activity monitoring, Titre 2 : systems and methods for evaluating enzyme competency, Pourcentage de similarité : 59.57446808510638%

# %%
df_filtre = df.filter(col("country").isNotNull() & col("publication_date").isNotNull())

# Distribution des brevets par pays, année de publication et inventeur
distribution_par_pays_annee_inventeur = df_filtre.select(
    "country",
    year("publication_date").alias("year"),
    explode("inventors").alias("inventor")
).groupBy("country", "year", "inventor").count().orderBy("country", "year", desc("count"))

# Affichage des résultats
distribution_par_pays_annee_inventeur.show(truncate=False)
# Out:
# +---------+----+--------------------+-----+
# |country  |year|inventor            |count|
# +---------+----+--------------------+-----+
# |Australia|2006|Wolfgang Rauscher   |1    |
# |Australia|2006|Michael Hodges      |1    |
# |Australia|2006|Thomas Giering      |1    |
# |Australia|2006|Oliver Martin       |1    |
# |Australia|2006|Graham Butler       |1    |
# |Australia|2006|Joachim Voelkening  |1    |
# |Australia|2006|Lysis Cubieres      |1    |
# |Australia|2006|Gerhard Schwenk     |1    |
# |Australia|2006|Yannick Mechine     |1    |
# |Australia|2006|Nicholas John Gudde |1    |
# |Australia|2007|Mircea Dan Bucevschi|1    |
# |Australia|2007|Tim Ulmasov         |1    |
# |Australia|2007|Neal A. Bringe      |1    |
# |Australia|2007|Joanne J. Fillatti  |1    |
# |Australia|2007|Toni Voelker        |1    |
# |Australia|2007|Monica Colt         |1    |
# |Australia|2007|Mendy Axlerad       |1    |
# |Australia|2008|Steve Verdino       |1    |
# |Australia|2008|John I. Compton     |1    |
# |Australia|2008|Mark E. Peters      |1    |
# +---------+----+--------------------+-----+

# %%
from pyspark.sql.functions import asc

# Distribution des brevets par pays, langue et inventeur
distribution_par_pays_langue_inventeur = df_filtre.select(
    "country",
    "other_language",
    explode("inventors").alias("inventor")
).groupBy("country", "other_language", "inventor").count().orderBy("country", asc("count"))

# Affichage des résultats
distribution_par_pays_langue_inventeur.show(truncate=False)
# Out:
# +---------+------------------+----------------------------+-----+
# |country  |other_language    |inventor                    |count|
# +---------+------------------+----------------------------+-----+
# |Australia|Helen Dacres      |Nam Cao Hoai Le             |1    |
# |Australia|Christopher Cooper|Thomas Craig Masterman      |1    |
# |Australia|Helen Dacres      |Nan Wu                      |1    |
# |Australia|Dieter H. Klaubert|James Unch                  |1    |
# |Australia|Dieter H. Klaubert|Poncho Meisenheimer         |1    |
# |Australia|Christopher Cooper|Marshall Medoff             |1    |
# |Australia|Stephen Ecob      |Stephen Ecob                |1    |
# |Australia|Helen Dacres      |Helen Dacres                |1    |
# |Australia|James M. Brennan  |Christopher Michael Mcginnis|1    |
# |Australia|James M. Brennan  |James M. Brennan            |1    |
# |Australia|Taras WANKEWYCZ   |Taras WANKEWYCZ             |1    |
# |Australia|Stephen Ecob      |Ian Oliver                  |1    |
# |Australia|James M. Brennan  |Eric Child Wilhelmsen       |1    |
# |Australia|Thomas Masterman  |Thomas Masterman            |1    |
# |Australia|Thomas Masterman  |Robert Paradis              |1    |
# |Australia|Helen Dacres      |Yonggang Zhu                |1    |
# |Australia|Christopher Cooper|Christopher Cooper          |1    |
# |Australia|Dieter H. Klaubert|Dieter H. Klaubert          |1    |
# |Australia|James M. Brennan  |Danny Elmer Lindstrom       |1    |
# |Australia|Helen Dacres      |Stephen Charles Trowell     |1    |
# +---------+------------------+----------------------------+-----+

# %%
from pyspark.sql.functions import year

# Filtrer les lignes avec des valeurs non nulles dans les colonnes "country" et "publication_date"
df_filtre = df.filter(col("country").isNotNull() & col("publication_date").isNotNull())

# Distribution des brevets par pays, année de publication et titre
distribution_par_pays_annee_titre = df_filtre.select(
    "country",
    year("publication_date").alias("year"),
    "title"
).groupBy("country", "year", "title").count().orderBy("country", "year", desc("count"))

# Affichage des résultats
distribution_par_pays_annee_titre.show(truncate=False)
# Out:
# +---------+----+-----------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |country  |year|title                                                                                                                                                |count|
# +---------+----+-----------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |Australia|2006|Portable apparatus for analysis of a refinery feedstock or a product of a refinery process                                                           |1    |
# |Australia|2006|Value document with luminescent properties                                                                                                           |1    |
# |Australia|2007|Nucleic acid constructs and methods for producing altered seed oil compositions                                                                      |1    |
# |Australia|2007|Polymeric materials as stomach filler and their preparation                                                                                          |1    |
# |Australia|2008|Method and system for calculating and reporting slump in delivery vehicles                                                                           |1    |
# |Australia|2009|Method for the Validatable Inactivation of Pathogens in Biological Fluid by Irradiation                                                              |1    |
# |Australia|2009|Barley lipoxygenase-1 gene, selection method for barley, materials for malt alcoholic beverages and method for production of malt alcoholic beverages|1    |
# |Australia|2009|Dual affinity polypeptides for purification                                                                                                          |1    |
# |Australia|2009|Method and device for determining a pressure parameter of a plant sample                                                                             |1    |
# |Australia|2013|Novel coelenterazine substrates and methods of use                                                                                                   |1    |
# |Australia|2014|Plant profile watering system                                                                                                                        |1    |
# |Australia|2014|Method and system for positioning an apparatus for monitoring a parabolic reflector aerially                                                         |1    |
# |Australia|2015|Methods and systems for detecting an analyte or classifying a sample                                                                                 |1    |
# |Australia|2015|Upgrading process streams                                                                                                                            |1    |
# |Australia|2015|Processing Biomass                                                                                                                                   |1    |
# |Australia|2017|An apparatus and system for providing a secondary power source for an electric vehicle                                                               |1    |
# |Australia|2018|Methods for the preparation of obeticholic acid and derivatives thereof                                                                              |1    |
# |Australia|2018|Processing Hydroxy-Carboxylic Acids To Polymers                                                                                                      |1    |
# |Australia|2019|Devices and methods for nucleic acid extraction                                                                                                      |1    |
# |Australia|2019|System for removal of toxic waste from woody materials                                                                                               |1    |
# +---------+----+-----------------------------------------------------------------------------------------------------------------------------------------------------+-----+

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# Connexion à la base de données PostgreSQL
conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="PostgreSQL_16",
    user="postgres",
    password="12345678"
)

# Créer un moteur SQLAlchemy pour pandas
engine = create_engine('postgresql://postgres:12345678@localhost:5432/PostgreSQL_16')

# Dictionnaire contenant les DataFrames Spark
dataframes_spark = {
    'Distribution_par_annee': distribution_par_annee,
    'Distribution_par_pays': distribution_par_pays,
    'Distribution_par_inventeur': distribution_par_inventeur,
    'Distribution_par_langue': distribution_par_langue,
    'Longueur_moyenne_description': longueur_moyenne_description,
    'Longueur_moyenne_revendications': longueur_moyenne_revendications,
    'Freq_mots_descriptions': freq_mots_descriptions,
    'Freq_mots_revendications': freq_mots_revendications,
    'Distribution_par_pays_et_annee': distribution_par_pays_et_annee,
    'Distribution_par_pays_et_revendications': distribution_par_pays_et_revendications,
    'Distribution_par_pays_annee_inventeur': distribution_par_pays_annee_inventeur,
    'Distribution_par_pays_langue_inventeur': distribution_par_pays_langue_inventeur,
    'Distribution_par_pays_annee_titre': distribution_par_pays_annee_titre
}

# Convertir les DataFrames Spark en DataFrames pandas et les insérer dans PostgreSQL
for df_name, df_spark in dataframes_spark.items():
    df_pandas = df_spark.toPandas()
    df_pandas.to_sql(df_name, engine, if_exists='replace', index=False)

# Fermer la connexion PostgreSQL
conn.close()

# %%
import psycopg2
from psycopg2 import sql

# Connexion à la base de données
conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="PostgreSQL_16",
    user="postgres",
    password="12345678"
)

# Création d'un curseur
cur = conn.cursor()

# Récupération de la liste des tables dans la base de données
cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public'")
tables = cur.fetchall()

# Parcours de chaque table et export des données
for table in tables:
    table_name = table[0]
    # Récupération des données de la table
    cur.execute(sql.SQL("SELECT * FROM {}").format(sql.Identifier(table_name)))
    data = cur.fetchall()
    
    # Écriture des données dans le fichier CSV avec l'encodage UTF-8
    with open(f"{table_name}.csv", "w", encoding="utf-8") as f:
        # Écriture de l'en-tête du fichier CSV avec les noms des colonnes
        cur.execute(sql.SQL("SELECT column_name FROM information_schema.columns WHERE table_name = %s"), (table_name,))
        columns = [col[0] for col in cur.fetchall()]
        f.write(','.join(columns) + '\n')
        
        # Écriture des données dans le fichier CSV
        for row in data:
            # Convertir chaque élément de la ligne en chaîne et le protéger contre les caractères spéciaux
            row_str = [str(elem).replace(',', '') if elem is not None else '' for elem in row]
            f.write(','.join(row_str) + '\n')


# Fermeture du curseur et de la connexion
cur.close()
conn.close()
